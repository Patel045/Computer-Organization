# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_axis5=[512,1024,2048,4096]
y_axis5=[12.5665,12.6145,12.6132,12.6205]
x_axis3=[1024,2048,4096]
y_axis3=[12.6144,12.6145,12.6192]
x_axis7=[512,1024]
y_axis7=[12.5665,12.6145]

# %%
plt.xlabel("Virtual Memory Size")
plt.ylabel("DTLB Miss Rate %")
plt.plot(x_axis5, y_axis5,"--go",label="5 Level of Table")  # Plot the chart
plt.plot(x_axis3, y_axis3,"--ro",label="3 Level of Table")  # Plot the chart
# plt.plot(x_axis7, y_axis7,"--bo",label="7 Level of Table")  # Plot the chart
plt.legend()
plt.show()  # display
